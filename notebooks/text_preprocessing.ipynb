# %%
print("hello")

# %%
print("hello world")
# Out:
# hello world

# %%
with open(
    "../artifacts/extracted_text/report.txt", "r", encoding="latin-1"
) as f:
    text = f.read()
print(text[:500])
# Out:
# MEDICAL LABORATORY REPORT
# Patient Information
# Patient Name: John Smith
# Age: 45 Years
# Gender: Male
# Patient ID: P123456
# Date of Test: 05 June 2026
# Complete Blood Count (CBC)
# Hemoglobin (Hb): 11.2 g/dL (Normal: 13.5 - 17.5 g/dL)
# White Blood Cells (WBC): 12,500 /µL (Normal: 4,000 - 11,000 /µL)
# Platelets: 250,000 /µL (Normal: 150,000 - 450,000 /µL)
# Blood Sugar
# Fasting Blood Sugar: 145 mg/dL (Normal: 70 - 99 mg/dL)
# HbA1c: 7.2% (Normal: Below 5.7%)
# Lipid Profile
# Total Cholesterol: 230 mg/dL
# LDL Cholest

# %%
print(len(text))
# Out:
# 874

# %%
words = text.split()
print(len(words))
# Out:
# 132

# %%
clean_text = " ".join(words)
print(clean_text[:500])
# Out:
# MEDICAL LABORATORY REPORT Patient Information Patient Name: John Smith Age: 45 Years Gender: Male Patient ID: P123456 Date of Test: 05 June 2026 Complete Blood Count (CBC) Hemoglobin (Hb): 11.2 g/dL (Normal: 13.5 - 17.5 g/dL) White Blood Cells (WBC): 12,500 /µL (Normal: 4,000 - 11,000 /µL) Platelets: 250,000 /µL (Normal: 150,000 - 450,000 /µL) Blood Sugar Fasting Blood Sugar: 145 mg/dL (Normal: 70 - 99 mg/dL) HbA1c: 7.2% (Normal: Below 5.7%) Lipid Profile Total Cholesterol: 230 mg/dL LDL Cholest

# %%
import re

clean_text = re.sub(r"\n+", "\n", text)

# %%
clean_text = clean_text.replace("\t", " ")

# %%
print("Raw Characters:", len(text))
print("Clean Characters:", len(clean_text))
# Out:
# Raw Characters: 874
# Clean Characters: 874

# %%
import re

clean_text = re.sub(r"\n+", "\n", text)

clean_text = clean_text.replace("\t", " ")

clean_text = " ".join(clean_text.split())

# %%
print("Raw Characters:", len(text))
print("Clean Characters:", len(clean_text))
# Out:
# Raw Characters: 874
# Clean Characters: 873

# %%
print(clean_text[:1000])
# Out:
# MEDICAL LABORATORY REPORT Patient Information Patient Name: John Smith Age: 45 Years Gender: Male Patient ID: P123456 Date of Test: 05 June 2026 Complete Blood Count (CBC) Hemoglobin (Hb): 11.2 g/dL (Normal: 13.5 - 17.5 g/dL) White Blood Cells (WBC): 12,500 /µL (Normal: 4,000 - 11,000 /µL) Platelets: 250,000 /µL (Normal: 150,000 - 450,000 /µL) Blood Sugar Fasting Blood Sugar: 145 mg/dL (Normal: 70 - 99 mg/dL) HbA1c: 7.2% (Normal: Below 5.7%) Lipid Profile Total Cholesterol: 230 mg/dL LDL Cholesterol: 150 mg/dL HDL Cholesterol: 38 mg/dL Triglycerides: 220 mg/dL Kidney Function Test Creatinine: 1.3 mg/dL Blood Urea Nitrogen (BUN): 24 mg/dL Doctor's Notes Patient shows elevated blood glucose levels suggesting Type 2 Diabetes. Cholesterol levels are above the recommended range. Mild anemia is present due to low hemoglobin levels. Follow-up consultation recommended.

# %%
with open(
    "../artifacts/clean_text/clean_report.txt", "w", encoding="latin-1"
) as f:
    f.write(clean_text)

# %%
with open(
    "../artifacts/clean_text/clean_report.txt",
    "r",
    encoding="latin-1"
) as f:

    data = f.read()

print(data[:1000])
# Out:
# MEDICAL LABORATORY REPORT Patient Information Patient Name: John Smith Age: 45 Years Gender: Male Patient ID: P123456 Date of Test: 05 June 2026 Complete Blood Count (CBC) Hemoglobin (Hb): 11.2 g/dL (Normal: 13.5 - 17.5 g/dL) White Blood Cells (WBC): 12,500 /µL (Normal: 4,000 - 11,000 /µL) Platelets: 250,000 /µL (Normal: 150,000 - 450,000 /µL) Blood Sugar Fasting Blood Sugar: 145 mg/dL (Normal: 70 - 99 mg/dL) HbA1c: 7.2% (Normal: Below 5.7%) Lipid Profile Total Cholesterol: 230 mg/dL LDL Cholesterol: 150 mg/dL HDL Cholesterol: 38 mg/dL Triglycerides: 220 mg/dL Kidney Function Test Creatinine: 1.3 mg/dL Blood Urea Nitrogen (BUN): 24 mg/dL Doctor's Notes Patient shows elevated blood glucose levels suggesting Type 2 Diabetes. Cholesterol levels are above the recommended range. Mild anemia is present due to low hemoglobin levels. Follow-up consultation recommended.
